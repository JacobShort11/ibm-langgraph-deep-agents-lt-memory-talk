# %% [markdown]
# # Daytona Sandbox Package Test
#
# Test which packages are available in the Daytona sandbox environment.

# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# Load .env
env_path = os.path.abspath(os.path.join(os.getcwd(), "..", ".env"))
if os.path.exists(env_path):
    with open(env_path) as f:
        for line in f:
            line = line.strip()
            if not line or line.startswith("#") or "=" not in line:
                continue
            k, v = line.split("=", 1)
            os.environ.setdefault(k, v)

from tools.code_execution import execute_python_code

# %% [markdown]
# ## Test Basic Packages (pandas, numpy, matplotlib, seaborn)

# %%
code = "import pandas as pd\nimport numpy as np\nimport matplotlib\nimport seaborn as sns\n\nprint('pandas version:', pd.__version__)\nprint('numpy version:', np.__version__)\nprint('matplotlib version:', matplotlib.__version__)\nprint('seaborn version:', sns.__version__)\nprint('\\nBasic packages: OK')"

result = execute_python_code(code)
print(result)
# Out:
# Output:
# pandas version: 2.2.3
# numpy version: 2.3.1
# matplotlib version: 3.10.3
# seaborn version: 0.13.2
#
# Basic packages: OK
#
# No plot files found to upload.

# %% [markdown]
# ## Test scipy

# %%
code = "import scipy\nprint('scipy version:', scipy.__version__)\nprint('scipy: OK')"

result = execute_python_code(code)
print(result)
# Out:
# Output:
# scipy version: 1.16.0
# scipy: OK
#
# No plot files found to upload.

# %% [markdown]
# ## Test sklearn

# %%
code = "import sklearn\nprint('sklearn version:', sklearn.__version__)\nfrom sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor\nfrom sklearn.linear_model import LinearRegression\nprint('GradientBoostingRegressor: OK')\nprint('RandomForestRegressor: OK')\nprint('LinearRegression: OK')\nprint('\\nsklearn: OK')"

result = execute_python_code(code)
print(result)
# Out:
# Output:
# sklearn version: 1.7.0
# GradientBoostingRegressor: OK
# RandomForestRegressor: OK
# LinearRegression: OK
#
# sklearn: OK
#
# No plot files found to upload.
